# %% [markdown]
# 2024-11-07 01:42:27,972 - INFO - Found 10 videos:
# 2024-11-07 01:42:27,973 - INFO - - Video: Bản sao của 0973453282 - 09/10 - B6 (ID: 10qe6DkNX6up7-oG69HRG3B4j1A-WiI_o)
# 2024-11-07 01:42:27,973 - INFO - - Video: Bản sao của 0383521988 - 08/10 - B28 (ID: 1wU7VG6RoQSIT4Nx3nzre3c9kf8IP3vPs)
# 2024-11-07 01:42:27,974 - INFO - - Video: Bản sao của 0912338926 - 09/10 - B10 (ID: 1cTQEfu1ftdHcHA42oDt4EphgjMI2yStD)
# 2024-11-07 01:42:27,974 - INFO - - Video: Bản sao của 0398678257 - 09/10 - B2 (ID: 1Bjc2DjRMKCg7-aTV7x4g8qGtBVcDxMT_)
# 2024-11-07 01:42:27,975 - INFO - - Video: Bản sao của 0961797200 - 09/10 - B13 (ID: 1x31CUa503coR26Tl-DIgMxiJaJmAWPmF)
# 2024-11-07 01:42:27,975 - INFO - - Video: Bản sao của 0989741503 - 10/10 - B12 (ID: 172JnO5uHq-ijmanNhDqZJtQQFZ2H3QN2)
# 2024-11-07 01:42:27,975 - INFO - - Video: Bản sao của 0377642151 - 09/10 - B16 (ID: 1Xj4nOZEf8-lWpub6AOSClmV81NOhkfRl)
# 2024-11-07 01:42:27,976 - INFO - - Video: Bản sao của 0949911296 - 09/10 - B16 (ID: 1oovK9faTksePgr5RF5H_UegY9VA1800D)
# 2024-11-07 01:42:27,976 - INFO - - Video: Bản sao của 0898347747 - 10/10 - B5 (ID: 1qetq0udB096mOpue8XyHtaUUYudB0k_Y)
# 2024-11-07 01:42:27,977 - INFO - - Video: Bản sao của 0345100005 - 09/10 - B17 (ID: 1ZDgW_R-vKmz3_A59y9UeicWXvWt2hoEL)
#
# -------
#
# Tôi có 1 database
#
# Khi sử dụng readDatabase
# ```python
# import sqlite3
# import os
#
# # Get database path
# current_dir = os.path.dirname(os.path.abspath(__file__))
# db_path = os.path.join(current_dir, 'video_database.db')
#
# # Connect to database
# conn = sqlite3.connect(db_path)
# cursor = conn.cursor()
#
# try:
#     # Show all tables
#     cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
#     print("Tables in database:", cursor.fetchall())
#
#     # Query videos table
#     cursor.execute('SELECT * FROM videos')   # tên bảng là videos đã tạo từ workflow.py
#     rows = cursor.fetchall()
#
#     # Print results
#     print(f"\nTotal records: {len(rows)}")
#     print("\nRecord details:")
#
#     for row in rows:
#         print("\n" + "="*50)
#         print(f"ID: {row[0]}")
#         print(f"Video URL: {row[1]}")
#         # print(f"Transcription: {row[2][:150]}...")  # Preview first 100 chars
#         # print(f"Criteria: {row[3]}...")       # Preview first 100 chars
#         # print(f"Created at: {row[4]}")
#
# except sqlite3.OperationalError as e:
#     print(f"Database error: {e}")
# except Exception as e:
#     print(f"Unexpected error: {e}")
# finally:
#     conn.close()
#
# ```
#
# -----------
# ```
#
# -------Thì tôi thu được
#
# Total records: 10
#
# Record details:
#
# ==================================================
#
# ID: 1
#
# Video URL: https://drive.google.com/file/d/10qe6DkNX6up7-oG69HRG3B4j1A-WiI_o/view
#
# ==================================================
#
# ID: 2
#
# Video URL: https://drive.google.com/file/d/1wU7VG6RoQSIT4Nx3nzre3c9kf8IP3vPs/view
#
# ==================================================
#
# ID: 3
#
# Video URL: https://drive.google.com/file/d/1Bjc2DjRMKCg7-aTV7x4g8qGtBVcDxMT_/view
#
# ==================================================
#
# ID: 4
#
# Video URL: https://drive.google.com/file/d/1x31CUa503coR26Tl-DIgMxiJaJmAWPmF/view
#
# ==================================================
#
# ID: 5
#
# Video URL: https://drive.google.com/file/d/172JnO5uHq-ijmanNhDqZJtQQFZ2H3QN2/view
#
# ==================================================
#
# ID: 6
#
# Video URL: https://drive.google.com/file/d/1Xj4nOZEf8-lWpub6AOSClmV81NOhkfRl/view
#
# ==================================================
#
# ID: 7
#
# Video URL: https://drive.google.com/file/d/1oovK9faTksePgr5RF5H_UegY9VA1800D/view
#
# ==================================================
#
# ID: 8
#
# Video URL: https://drive.google.com/file/d/1qetq0udB096mOpue8XyHtaUUYudB0k_Y/view
#
# ==================================================
#
# ID: 9
#
# Video URL: https://drive.google.com/file/d/1ZDgW_R-vKmz3_A59y9UeicWXvWt2hoEL/view
#
# ==================================================
#
# ID: 10
#
# Video URL: https://drive.google.com/file/d/1cTQEfu1ftdHcHA42oDt4EphgjMI2yStD/view
#
#
# -------
#                 CREATE TABLE IF NOT EXISTS videos (
#                     id INTEGER PRIMARY KEY,
#                     url_video TEXT NOT NULL UNIQUE,
#                     transcription TEXT,
#                     criteria TEXT,
#                     created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
#                 )
# ----------
# Giờ muốn update thêm 1 cột: name_video nữa
